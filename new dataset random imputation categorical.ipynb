# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\himanshu\\Downloads\\train (1).csv")
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
df.shape
# Out:
# (18, 12)

# %%
df.size
# Out:
# 216

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  18 non-null     int64
#  1   Survived     18 non-null     int64
#  2   Pclass       18 non-null     int64
#  3   Name         18 non-null     object
#  4   Sex          18 non-null     object
#  5   Age          16 non-null     float64
#  6   SibSp        18 non-null     int64
#  7   Parch        18 non-null     int64
#  8   Ticket       18 non-null     object
#  9   Fare         18 non-null     float64
#  10  Cabin        5 non-null      object
#  11  Embarked     14 non-null     object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 1.8+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age             2
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin          13
# Embarked        4
# dtype: int64

# %%
df.isnull().mean()
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.111111
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.722222
# Embarked       0.222222
# dtype: float64

# %%
df.describe()
# Out:
#        PassengerId   Survived     Pclass       Age      SibSp      Parch  \
# count    18.000000  18.000000  18.000000  16.00000  18.000000  18.000000
# mean      9.500000   0.500000   2.388889  27.81250   0.722222   0.555556
# std       5.338539   0.514496   0.849837  18.34564   1.127494   1.247219
# min       1.000000   0.000000   1.000000   2.00000   0.000000   0.000000
# 25%       5.250000   0.000000   2.000000  14.00000   0.000000   0.000000
# 50%       9.500000   0.500000   3.000000  26.50000   0.000000   0.000000
# 75%      13.750000   1.000000   3.000000  38.25000   1.000000   0.750000
# max      18.000000   1.000000   3.000000  58.00000   4.000000   5.000000
#
#             Fare
# count  18.000000
# mean   23.264578
# std    18.683202
# min     7.250000
# 25%     8.152075
# 50%    16.350000
# 75%    29.834350
# max    71.283300

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        s
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        Q
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 15           16         1       2      Hewlett, Mrs. (Mary D Kingcome)
# 16           17         0       3                  Rice, Master. Eugene
# 17           18         1       2          Williams, Mr. Charles Eugene
#
#        Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 13    male  39.0      1      5  347082  31.2750   NaN        S
# 14  female  14.0      0      0  350406   7.8542   NaN      NaN
# 15  female  55.0      0      0  248706  16.0000   NaN        S
# 16    male   2.0      4      1  382652  29.1250   NaN        Q
# 17    male   NaN      0      0  244373  13.0000   NaN        S

# %%
df["Embarked_imputed"]=df["Embarked"]

# %%
df.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
df["Embarked_imputed"][df["Embarked"].isnull()]=df["Embarked"].dropna().sample(df["Embarked"].isnull().sum()).values
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_7772\935475490.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Embarked_imputed"][df["Embarked"].isnull()]=df["Embarked"].dropna().sample(df["Embarked"].isnull().sum()).values

# %%
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
df["Embarked"][df['Embarked'].isnull()]=df["Embarked"].dropna().sample(df["Embarked"].isnull().sum()).values
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_7772\917547778.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Embarked"][df['Embarked'].isnull()]=df["Embarked"].dropna().sample(df["Embarked"].isnull().sum()).values

# %%
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# ...
